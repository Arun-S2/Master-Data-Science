# %%
# PYTHON BASICS

# VARIABLES

"""Conditions of variables:
   # A variable name must start with a letter or the underscore character.
   # A variable name cannot start with a number.
   # A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
   # Variable names are case-sensitive (age, Age and AGE are three different variables)"""


# Correct variables:

    a = 'python'               # Variable 'a' assigned to a string 'python'.

    a8 = 'python'              # Alpha-numerical

    _a8 = 'python'             # Starts with a underscore

    python = 'python'          # Variable 'python' assigned to a string 'python'.

    PYTHON = 'python'          # Variable 'PYTHON' assigned to a string 'python'.

    PyThOn = "python"          # The above 3 variables(python,PYTHON and PyThOn) are different from each other becoz of case-sensitive.


"""Incorrect variables

    A B = 'python'          # Variables shouldn't contain space in between

    8a = 'python'           # Variables should not start with a number

    a*8 = "python"          # Special characters are not premitted

    True = 'python'         # True is a boolean, So it can't be used as a variable"""


# ASSING VALUES TO VARIABLES

    # single value to single variable:

    a = 10
    or
    b = 'python'

    # single value to many variable:

    a = b = c = 10

    # Many value to many variable:

    a,b,c = 10,20,30




"""DATA TYPES
    1.NUMERICAL
        # Integer
            It is a hole number
                eg: 1
                    2
                    45
                    678
        # Float
            It is a number with decimal values
                eg: 3.5
                    50.8
                    1.1
                    3.456
        # Complex
            The complex data type in python consists of two values,
            The first one is the real part of the complex number, and
            The second one is the imaginary part of the complex number.
                eg : 3j
                     5i
                     6i
    2.SEQUENCES
        # String
            a string is a sequence of characters enclosed within either single quotes (' ') or double quotes (" ").
            It is an immutable data type,
            Which means once a string is created, it cannot be modified.
                eg : ('python')
                     ("python")
                     ('2000')
                     
        # List (Create,Access,Modify and delete)
            The list data type in Python is used to store multiple items in a single variable.
            List uses primary and secondary memory it make little slow compare to Tuple,
            Lists are 
                # Ordered,
                    The items have a defined order, and that order will not change.
                    If you add new items to a list, the new items will be placed at the end of the list.
                # Mutable (Can be modified after creation), and 
                # dir(variable) to know the functions in jupitor note book
                # Can contain elements of different data types.
                    eg : [10,'python',50.5]
                         ['Hello','World',10,30,'program',[3,'Hello']]
                     
        # Tupple (Create,Access and delete)
            Tuples are a type of data structure that is very similar to lists.
            The main difference between the two is that tuples are immutable
            Tuple is faster than list
            Tuple uses primary memory only.It makes tuple faster.
                # Ordered
                    The items have a defined order, and that order will not change.
                # Immutable
                    Can't be changed after creation,
                    It also can be done change the tuple to list and again list to tuple.
                # dir(variable) to know the functions in jupitor note book
                # Can contain elements of different data types.
                    eg : (10,'python',50.5)
                         ('Hello','World',10,30,'program',[3,'Hello'])

        # Set (Create,Access, Modify and delete)
            # Unordered
                The value we give will be ordered like 1,2,3,4.
            # Set doesn't have index, Can't access values through index value.
            # Unique values
                Does not allow duplicate values.Duplicate values will be mearged.
                    eg : Right - {4,7,2,8,34,65} Stroed in like {2,4,7,8,34,65}
                         Wrong - {4,7,2,8,34,7,2} Stroed in like {2,4,7,8,34} 
            # Can be add or remove values
    
    3.BOOLEAN
        which represents one of the two values i.e. True or False.
    
    4.DICTIONARY
        Dictionary is a data type that stores data values as key: values pair.
        It is written in curly brackets with comma-separated key: value pair.
        Dict is an ordered collection of elements that allow the addition, update, and deletion of items.
        Dict allows retrieving values using keys.
            eg : D = {'Name':'Python','Type':'Language'}
                print(D['Name'])
                Result= Python
